# %% [markdown]
# # PDF

# %%
def get_pdf_probability(dataset,startrange,endrange):
    from matplotlib import pyplot#library
    from scipy.stats import norm#library
    import seaborn as sns#library for visualization
    ax = sns.distplot(dataset,kde=True,kde_kws={'color':'Blue'},color='yellow')#kde=kernal density used to create curve in the plot
    pyplot.axvline(startrange,color='Red')#axvline = axis vertical line,starting range
    pyplot.axvline(endrange,color='Red')#ending range
    # generate a sample
    sample = dataset # sample datset
    # calculate parameters
    sample_mean =sample.mean() #finding mean and SD to calculate the code
    sample_std = sample.std()
    print('Mean=%.3f, Standard Deviation=%.3f' % (sample_mean, sample_std))
    # define the distribution
    dist = norm(sample_mean, sample_std)
    
    # sample probabilities for a range of outcomes
    values = [value for value in range(startrange, endrange)]#range convert into list by using this line of code
    probabilities = [dist.pdf(value) for value in values]    
    prob=sum(probabilities)
    print("The area between range({},{}):{}".format(startrange,endrange,sum(probabilities)))
    return prob

# %% [markdown]
# #This code defines a function named get_pdf_probability that calculates the probability of a range in a given dataset based on the probability density function (PDF) of the normal distribution.
#
#
# # Importing Libraries:
#
# from matplotlib import pyplot
# from scipy.stats import norm
# import seaborn as sns
# The code imports necessary libraries: pyplot for plotting, norm from scipy.stats for working with normal distributions, and seaborn for visualization.
#
# # Plotting the Dataset:
#
# ax = sns.distplot(dataset, kde=True, kde_kws={'color':'Blue'}, color='yellow')
# This line uses Seaborn to plot the distribution of the dataset. The kernel density estimate (kde) is displayed in blue, and the histogram is filled with a yellow color.
#
# # Drawing Vertical Lines for Range:
#
# pyplot.axvline(startrange, color='Red')
# pyplot.axvline(endrange, color='Red')
# Vertical red lines are drawn at the specified start and end ranges.
#
# # Calculating Mean and Standard Deviation:
#
# sample_mean = sample.mean()
# sample_std = sample.std()
# The code calculates the mean and standard deviation of the input dataset.
#
# # Defining the Distribution:
#
# dist = norm(sample_mean, sample_std)
# This line defines a normal distribution with the calculated mean and standard deviation.
#
# # Calculating Probabilities:
#
# values = [value for value in range(startrange, endrange)]
# probabilities = [dist.pdf(value) for value in values]
# The code generates a list of values within the specified range and calculates the probability density function (PDF) for each value based on the normal distribution.
#
# # Printing and Returning Probability:
#
# prob = sum(probabilities)
# print("The area between range({},{}):{}".format(startrange, endrange, sum(probabilities)))
# return prob
# The total probability within the specified range is calculated by summing the individual probabilities. The function prints this total probability and returns it.
#
# In summary, this function visualizes the dataset, marks a specified range with red vertical lines, calculates the mean and standard deviation of the dataset, defines a normal distribution, and then calculates and prints the total probability within the specified range based on the PDF of the normal distribution.

# %% [markdown]
# # Standard normal Distribution

# %%
def stdNBgraph(dataset):
        # Coverted to standard Normal Distribution
    import seaborn as sns
    mean=dataset.mean()
    std=dataset.std()

    values=[i for i in dataset]

    z_score=[((j-mean)/std) for j in values]

    sns.distplot(z_score,kde=True)

    sum(z_score)/len(z_score)
    #z_score.std()

# %% [markdown]
# This code appears to be defining a function named stdNBgraph that takes a dataset as input and creates a standard normal distribution plot using the seaborn library in Python.
#
# # Importing Libraries:
#
# import seaborn as sns
# This line imports the Seaborn library, which is commonly used for statistical data visualization.
#
# # Calculating Mean and Standard Deviation:
#
# mean = dataset.mean()
# std = dataset.std()
# These lines calculate the mean and standard deviation of the input dataset.
#
# # Creating Values and Z-Scores:
#
#
# values = [i for i in dataset]
# z_score = [((j - mean) / std) for j in values]
# The code creates a list of values from the dataset and then calculates the Z-scores for each value using the formula:
# (
# value
# −
# mean
# )
# /
# std
# (value−mean)/std.
#
# # Plotting the Standard Normal Distribution:
#
# sns.distplot(z_score, kde=True)
# This line uses Seaborn's distplot function to plot the distribution of the calculated Z-scores. The kde=True argument adds a kernel density estimate to the plot.
#
# # Calculating and Displaying the Mean of Z-Scores:
#
# sum(z_score) / len(z_score)
# This line calculates the mean of the Z-scores, but the result is not stored or displayed. You might want to assign the result to a variable or use a print statement to display it.
#
# Note:
# The line #z_score.std() is commented out. If you want to calculate and display the standard deviation of the Z-scores, you should uncomment this line.
#
# In summary, this function takes a dataset, converts it to Z-scores (standard normal distribution), and then visualizes the distribution using Seaborn. The mean of the Z-scores is calculated, but the result is not currently used or displayed in the code.
